# %%
import pandas as pd

# %%
a=pd.read_csv("airquality_data.csv", encoding='latin1')
# Out:
# C:\Users\user5\AppData\Local\Temp\ipykernel_20876\316551039.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   a=pd.read_csv("airquality_data.csv", encoding='latin1')

# %%
#Data cleaning
a.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5        date
# 0                         NaN    NaN  1990-02-01
# 1                         NaN    NaN  1990-02-01
# 2                         NaN    NaN  1990-02-01
# ...

# %%
a.shape
# Out:
# (435742, 13)

# %%
a.isnull()
# Out:
#         stn_code  sampling_date  state  location  agency   type    so2    no2  \
# 0          False          False  False     False    True  False  False  False
# 1          False          False  False     False    True  False  False  False
# 2          False          False  False     False    True  False  False  False
# 3          False          False  False     False    True  False  False  False
# 4          False          False  False     False    True  False  False  False
# ...          ...            ...    ...       ...     ...    ...    ...    ...
# 435737     False          False  False     False   False  False  False  False
# 435738     False          False  False     False   False  False  False  False
# 435739      True           True  False      True    True   True   True   True
# 435740      True           True  False      True    True   True   True   True
# 435741      True           True  False      True    True   True   True   True
#
# ...

# %%
a.isnull().any()
# Out:
# stn_code                        True
# sampling_date                   True
# state                          False
# location                        True
# agency                          True
# type                            True
# so2                             True
# no2                             True
# rspm                            True
# spm                             True
# location_monitoring_station     True
# pm2_5                           True
# date                            True
# dtype: bool

# %%
a.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
#remove null values
b=a.dropna()

# %%
b
# Out:
# Empty DataFrame
# Columns: [stn_code, sampling_date, state, location, agency, type, so2, no2, rspm, spm, location_monitoring_station, pm2_5, date]
# Index: []

# %%
b.shape
# Out:
# (0, 13)

# %%
#fill null values with 0
b=a.fillna(0)

# %%
b
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739        0                   0  andaman-and-nicobar-islands          0
# 435740        0                   0                  Lakshadweep          0
# 435741        0                   0                      Tripura          0
#
#                                            agency  \
# ...

# %%
b=a.fillna(method='pad')
b
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739     SAMP            29-12-15  andaman-and-nicobar-islands   ULUBERIA
# 435740     SAMP            29-12-15                  Lakshadweep   ULUBERIA
# 435741     SAMP            29-12-15                      Tripura   ULUBERIA
#
#                                            agency  \
# ...

# %%
b=a.fillna(method='backfill')
b
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
c=a.drop_duplicates()

# %%
c.shape
# Out:
# (435068, 13)

# %%
#error correcting remove outliers
a = a[(a['no2'] < a['no2'].quantile(0.95)) & (a['so2'] < a['so2'].quantile(0.95))]
a
# Out:
#        stn_code       sampling_date           state   location  \
# 0         150.0  February - M021990  Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990  Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990  Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990  Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990  Andhra Pradesh  Hyderabad
# ...         ...                 ...             ...        ...
# 435734     SAMP            15-12-15     West Bengal   ULUBERIA
# 435735     SAMP            18-12-15     West Bengal   ULUBERIA
# 435736     SAMP            21-12-15     West Bengal   ULUBERIA
# 435737     SAMP            24-12-15     West Bengal   ULUBERIA
# 435738     SAMP            29-12-15     West Bengal   ULUBERIA
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# ...

# %%
a.shape
# Out:
# (362160, 13)

# %%
ds=pd.read_csv("heart.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed #error correction

for col in 'age':
    sns.boxplot(data=ds['age'])
    plt.title(col)
    plt.show()

# %%
#data integration
ds1=a.iloc[[1,2,3,4,5],[2,3,6,8]]
ds2=ds.iloc[[1,2,3,4,5],[0,1,2,6]]

# %%
ds1
# Out:
#             state   location  so2  rspm
# 1  Andhra Pradesh  Hyderabad  3.1   NaN
# 2  Andhra Pradesh  Hyderabad  6.2   NaN
# 3  Andhra Pradesh  Hyderabad  6.3   NaN
# 4  Andhra Pradesh  Hyderabad  4.7   NaN
# 5  Andhra Pradesh  Hyderabad  6.4   NaN

# %%
ds2
# Out:
#    age  sex  cp  restecg
# 1   37    1   2        1
# 2   41    0   1        0
# 3   56    1   1        1
# 4   57    0   0        1
# 5   57    1   0        1

# %%
c=pd.merge(ds1,ds2, how='cross')
c
# Out:
#              state   location  so2  rspm  age  sex  cp  restecg
# 0   Andhra Pradesh  Hyderabad  3.1   NaN   37    1   2        1
# 1   Andhra Pradesh  Hyderabad  3.1   NaN   41    0   1        0
# 2   Andhra Pradesh  Hyderabad  3.1   NaN   56    1   1        1
# 3   Andhra Pradesh  Hyderabad  3.1   NaN   57    0   0        1
# 4   Andhra Pradesh  Hyderabad  3.1   NaN   57    1   0        1
# 5   Andhra Pradesh  Hyderabad  6.2   NaN   37    1   2        1
# 6   Andhra Pradesh  Hyderabad  6.2   NaN   41    0   1        0
# 7   Andhra Pradesh  Hyderabad  6.2   NaN   56    1   1        1
# 8   Andhra Pradesh  Hyderabad  6.2   NaN   57    0   0        1
# 9   Andhra Pradesh  Hyderabad  6.2   NaN   57    1   0        1
# 10  Andhra Pradesh  Hyderabad  6.3   NaN   37    1   2        1
# 11  Andhra Pradesh  Hyderabad  6.3   NaN   41    0   1        0
# 12  Andhra Pradesh  Hyderabad  6.3   NaN   56    1   1        1
# 13  Andhra Pradesh  Hyderabad  6.3   NaN   57    0   0        1
# ...

# %%
ds3=ds.iloc[[1,2,3,4,5],[0,2,3,4]]
ds4=ds.iloc[[7,8,9,10,12],[0,5,6,7]]
ds3
# Out:
#    age  cp  trtbps  chol
# 1   37   2     130   250
# 2   41   1     130   204
# 3   56   1     120   236
# 4   57   0     120   354
# 5   57   0     140   192

# %%
ds4
# Out:
#     age  fbs  restecg  thalachh
# 7    44    0        1       173
# 8    52    1        1       162
# 9    57    0        1       174
# 10   54    0        1       160
# 12   49    0        1       171

# %%
mds=pd.merge(ds3,ds4, on='age', how='inner')
mds
# Out:
#    age  cp  trtbps  chol  fbs  restecg  thalachh
# 0   57   0     120   354    0        1       174
# 1   57   0     140   192    0        1       174

# %%
#data Transformation
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
#scale values between 1 to 10
x=scaler.fit_transform(ds) #heart dataset

# %%
pd.DataFrame(x).describe()
# Out:
#                  0             1             2             3             4   \
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean   4.690051e-17 -1.407015e-16  2.345026e-17 -7.035077e-16 -1.113887e-16
# std    1.001654e+00  1.001654e+00  1.001654e+00  1.001654e+00  1.001654e+00
# min   -2.797624e+00 -1.468418e+00 -9.385146e-01 -2.148802e+00 -2.324160e+00
# 25%   -7.572802e-01 -1.468418e+00 -9.385146e-01 -6.638668e-01 -6.814943e-01
# 50%    6.988599e-02  6.810052e-01  3.203122e-02 -9.273778e-02 -1.210553e-01
# 75%    7.316189e-01  6.810052e-01  1.002577e+00  4.783913e-01  5.456738e-01
# max    2.496240e+00  6.810052e-01  1.973123e+00  3.905165e+00  6.140401e+00
#
#                  5             6             7             8             9   \
# count  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02  3.030000e+02
# mean  -2.345026e-17  1.465641e-16 -6.800574e-16 -4.690051e-17  2.345026e-17
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
#scaling between 0 to 1
scaler=MinMaxScaler()

# %%
y=scaler.fit_transform(ds)
pd.DataFrame(y).describe()
# Out:
#                0           1           2           3           4           5   \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528465    0.683168    0.322332    0.354941    0.274575    0.148515
# std      0.189210    0.466011    0.344017    0.165454    0.118335    0.356198
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.385417    0.000000    0.000000    0.245283    0.194064    0.000000
# 50%      0.541667    1.000000    0.333333    0.339623    0.260274    0.000000
# 75%      0.666667    1.000000    0.666667    0.433962    0.339041    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                6           7           8           9           10          11  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.264026    0.600358    0.326733    0.167678    0.699670    0.182343
# ...

# %%
#convert string to number
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
z=le.fit_transform(a['location'])#location column of airquality dataset
z
# Out:
# array([114, 114, 114, ..., 304, 304, 304])

# %%
z=a[:]

# %%
z['location']=le.fit_transform(z['location'])
z
# Out:
#        stn_code       sampling_date                        state  location  \
# 0         150.0  February - M021990               Andhra Pradesh       114
# 1         151.0  February - M021990               Andhra Pradesh       114
# 2         152.0  February - M021990               Andhra Pradesh       114
# 3         150.0     March - M031990               Andhra Pradesh       114
# 4         151.0     March - M031990               Andhra Pradesh       114
# ...         ...                 ...                          ...       ...
# 435737     SAMP            24-12-15                  West Bengal       282
# 435738     SAMP            29-12-15                  West Bengal       282
# 435739      NaN                 NaN  andaman-and-nicobar-islands       304
# 435740      NaN                 NaN                  Lakshadweep       304
# 435741      NaN                 NaN                      Tripura       304
#
#                                            agency  \
# ...

# %%
#spliting dataset
from sklearn.model_selection import train_test_split

# %%
#data model building
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
z=ds[['age','sex','cp','chol','fbs']]
z1=ds.output

# %%
z
# Out:
#      age  sex  cp  chol  fbs
# 0     63    1   3   233    1
# 1     37    1   2   250    0
# 2     41    0   1   204    0
# 3     56    1   1   236    0
# 4     57    0   0   354    0
# ..   ...  ...  ..   ...  ...
# 298   57    0   0   241    0
# 299   45    1   3   264    0
# 300   68    1   0   193    1
# 301   57    1   0   131    0
# 302   57    0   1   236    0
#
# [303 rows x 5 columns]

# %%
z1
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64

# %%
z_train, z_test, z1_train, z1_test = train_test_split(z, z1, test_size=0.2, random_state=42)

# %%
len(z_train)
# Out:
# 242

# %%
len(z_test)
# Out:
# 61

# %%
ds.shape
# Out:
# (303, 14)

# %%
model=LogisticRegression()
model.fit(z_train,z1_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(z_test)

# %%
accuracy = accuracy_score(z1_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7540983606557377
